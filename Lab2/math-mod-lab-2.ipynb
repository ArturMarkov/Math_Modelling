# %% [markdown]
# # Lab 2

# %%
import numpy as np
import scipy.signal as sig

import plotly.graph_objects as go

# %%
def plot(x,y,name_):
    
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=t, y=y))
    fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='black')
    fig.update_xaxes(zeroline=True, zerolinewidth=1, zerolinecolor='black')
    fig.update_layout(legend_orientation="h",
                    title=name_,
                    legend=dict(x=.5, xanchor="center")
                    #margin=dict(l=0, r=0, t=0, b=0)
                    )

    #fig.update_yaxes(range=[-500,200])
    #fig.update_xaxes(range=[-0.5, 10])
    return fig.show()

# %% [markdown]
# ## Transfer function representation

# %%
num = np.array([1,-1,1,-1])
denom_un = np.array([1,0,1,4])
denom_st = np.array([1,5,1,4])

# %% [markdown]
# ## Loop

# %%
def add_loop(numerator, denominator, k):
     return (k*num, denom- k*num)

def sub_loop(numerator, denominator, k):
    return (k*num, denom + k*num)

# %%
print(f"Physical implementability:  {num.shape[0] <= denom_st.shape[0]}")
# Out:
# Physical implementability:  True

# %% [markdown]
# ## ZPK

# %% [markdown]
# ### Unstable system

# %%
z,p,k = sig.tf2zpk(num, denom_un)

# %%
def print_zpk(z, p, k):
    print(f"Zeros: {np.round(z, 2)}",f"Poles: {np.round(p, 2)}",f"Poles: {np.round(p, 2)}",f"Koeff: {k}",sep="\n")

    print(f"System stability: {~np.any(p.real > 0)}")

# %%
print_zpk(z, p, k)
# Out:
# Zeros: [1.+0.j 0.+1.j 0.-1.j]
# Poles: [-4.96+0.j  -0.02+0.9j -0.02-0.9j]
# Poles: [-4.96+0.j  -0.02+0.9j -0.02-0.9j]
# Koeff: 1.0
# System stability: True

# %%
t,y = sig.step((num, denom_un))

plot(t, y,name_="Step response")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="5ebd8c88-5faf-4cbb-b3d5-4b94380d30a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ebd8c88-5faf-4cbb-b3d5-4b94380d30a7")) {                    Plotly.newPlot(                        "5ebd8c88-5faf-4cbb-b3d5-4b94380d30a7",                        [{"type": "scatter", "x": [0.0, 0.10256344637382303, 0.20512689274764606, 0.3076903391214691, 0.4102537854952921, 0.5128172318691151, 0.6153806782429382, 0.7179441246167613, 0.8205075709905842, 0.9230710173644072, 1.0256344637382302, 1.1281979101120534, 1.2307613564858764, 1.3333248028596993, 1.4358882492335225, 1.5384516956073455, 1.6410151419811685, 1.7435785883549915, 1.8461420347288144, 1.9487054811026376, 2.0512689274764604, 2.1538323738502836, 2.256395820224107, 2.3589592665979295, 2.4615227129717527, 2.564086159345576, 2.6666496057193987, 2.769213052093222, 2.871776498467045, 2.974339944840868, 3.076903391214691, 3.179466837588514, 3.282030283962337, 3.38459373033616, 3.487157176709983, 3.589720623083806, 3.692284069457629, 3.794847515831452, 3.8974109622052753, 3.999974408579098, 4.102537854952921, 4.205101301326744, 4.307664747700567, 4.41022819407439, 4.512791640448214, 4.615355086822037, 4.717918533195859, 4.820481979569682, 4.9230454259435055, 5.025608872317329, 5.128172318691152, 5.230735765064974, 5.333299211438797, 5.435862657812621, 5.538426104186444, 5.640989550560267, 5.74355299693409, 5.8461164433079125, 5.948679889681736, 6.051243336055559, 6.153806782429382, 6.256370228803205, 6.358933675177028, 6.461497121550851, 6.564060567924674, 6.666624014298497, 6.76918746067232, 6.871750907046143, 6.974314353419966, 7.076877799793789, 7.179441246167612, 7.2820046925414355, 
#     \dfrac{dq}{dt} &= \textbf{A}q + \textbf{B}x \\
#     y &= \textbf{C}q + \textbf{D}x
# \end{cases}
# $$

# %%
A,B,C,D = sig.zpk2ss(z, p, k)

# %%
def observable(A,B,C,D):    
    T = np.empty_like(A)
    for i in range(A.shape[0]):
        T[i, :] = (np.dot(np.linalg.matrix_power(A, i).T, C.T)).reshape(A.shape[0])    
    
    An = T.dot(A).dot(np.linalg.inv(T))
    Bn = np.dot(T,B)
    Cn = np.dot(C,np.linalg.inv(T))    
    return An, Bn, Cn, D

def controlable(A,B, C, D):
    T = np.empty_like(A)
    for i in range(A.shape[0]):
        T[:, i] = (np.linalg.matrix_power(A, i).dot(B)).reshape(A.shape[0])    
        
    An = np.linalg.inv(T).dot(A).dot(T)
    Bn = np.dot(np.linalg.inv(T),B)
    Cn = np.dot(C,T)
    return An, Bn, Cn, D

# %%
print("Observable canonical form")
print(np.round(observable(A, B, C, D)[0], 3))
# Out:
# Observable canonical form
# [[-0.  1. -0.]
#  [-0. -0.  1.]
#  [-4. -1. -5.]]

# %%
print("Controlable canonical form")
print(np.round(controlable(A, B, C, D)[0], 3))
# Out:
# Controlable canonical form
# [[ 0.  0. -4.]
#  [ 1.  0. -1.]
#  [ 0.  1. -5.]]

# %% [markdown]
# System obsevable if
#
# $ \mathrm{rank}
# \begin{pmatrix}
#     C \\
#     CA \\
#     CA^2 \\
#     \dots \\
#     CA^{n-1}
# \end{pmatrix} = n $
#
# System controlable if
#
# $ \mathrm{rank}
# \begin{pmatrix}
#     B \;
#     AB \;
#     A^2B \;
#     \dots \;
#     A^{n-1}B
# \end{pmatrix} = n$

# %%
def validate_observable(A, C):
    T = np.empty_like(A)
    for i in range(A.shape[0]):
        T[:, i] = (C @ np.linalg.matrix_power(A, i)).reshape(A.shape[0])
    return np.linalg.matrix_rank(T) == A.shape[0]

def validate_controlable(A, B):
    T = np.empty_like(A)
    for i in range(A.shape[1]):
        T[i, :] = (np.linalg.matrix_power(A, i) @ B).reshape(A.shape[0])
    return np.linalg.matrix_rank(T) == A.shape[0]

# %%
print(f"System controlability: {validate_controlable(A, B)}")
print(f"System observability: {validate_observable(A, C)}")
# Out:
# System controlability: True
# System observability: True

# %%
num2, denom2 = sig.ss2tf(A,B,C,D)

# %%
t, y1 = sig.step((num, denom_st))
t, y2 = sig.step((num2, denom2))

plot(t,y1 - y2,"Difference of Step response")
# Out:
# <div>                            <div id="048562e0-4613-44fb-803e-538c2f64b528" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("048562e0-4613-44fb-803e-538c2f64b528")) {                    Plotly.newPlot(                        "048562e0-4613-44fb-803e-538c2f64b528",                        [{"type": "scatter", "x": [0.0, 3.6217672452822636, 7.243534490564527, 10.86530173584679, 14.487068981129054, 18.108836226411317, 21.73060347169358, 25.352370716975845, 28.97413796225811, 32.59590520754037, 36.21767245282263, 39.8394396981049, 43.46120694338716, 47.082974188669425, 50.70474143395169, 54.32650867923395, 57.94827592451622, 61.57004316979848, 65.19181041508074, 68.81357766036301, 72.43534490564527, 76.05711215092754, 79.6788793962098, 83.30064664149207, 86.92241388677432, 90.5441811320566, 94.16594837733885, 97.78771562262112, 101.40948286790338, 105.03125011318565, 108.6530173584679, 112.27478460375018, 115.89655184903243, 119.51831909431469, 123.